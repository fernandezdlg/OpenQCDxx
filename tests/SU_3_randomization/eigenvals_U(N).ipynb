# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import the eigenvalues.csv data
data = np.genfromtxt('eigenvalues_HH.csv', delimiter=',')
# Extract the first column
x = data[1:,0]
# Extract the second column
y = data[1:,1]

# Plot the data in histogram
plt.hist(y, bins=100, log=True)
plt.xlabel('Eigenvalues')
plt.ylabel('Frequency')
plt.title('Histogram of eigenvalues')
plt.show()

del(data, x, y)

# %%
# Import the eigenvalues.csv data
data = np.genfromtxt('eigenvalues_HH_corr.csv', delimiter=',')
# Extract the first column
x = data[1:,0]
# Extract the second column
y = data[1:,1]

# Plot the data in histogram
plt.hist(y, bins=100, log=True)
plt.xlabel('Eigenvalues')
plt.ylabel('Frequency')
plt.title('Histogram of eigenvalues')
plt.show()

del(data, x, y)

# %%
# Import the eigenvalues.csv data
data = np.genfromtxt('eigenvalues_colpiv.csv', delimiter=',')
# Extract the first column
x = data[1:,0]
# Extract the second column
y = data[1:,1]

# Plot the data in histogram
plt.hist(y, bins=100, log=True)
plt.xlabel('Eigenvalues')
plt.ylabel('Frequency')
plt.title('Histogram of eigenvalues')
plt.show()

del(data, x, y)

# %%
# Import the eigenvalues.csv data
data = np.genfromtxt('eigenvalues_colpiv_corr.csv', delimiter=',')
# Extract the first column
x = data[1:,0]
# Extract the second column
y = data[1:,1]

# Plot the data in histogram
plt.hist(y, bins=100, log=True)
plt.xlabel('Eigenvalues')
plt.ylabel('Frequency')
plt.title('Histogram of eigenvalues')
plt.show()

del(data, x, y)

# %%
# Import the eigenvalues.csv data
data = np.genfromtxt('eigenvalues_fullpiv.csv', delimiter=',')
# Extract the first column
x = data[1:,0]
# Extract the second column
y = data[1:,1]

# Plot the data in histogram
plt.hist(y, bins=100, log=True)
plt.xlabel('Eigenvalues')
plt.ylabel('Frequency')
plt.title('Histogram of eigenvalues')
plt.show()

del(data, x, y)

# %%
# Import the eigenvalues.csv data
data = np.genfromtxt('eigenvalues_fullpiv_corr.csv', delimiter=',')
# Extract the first column
x = data[1:,0]
# Extract the second column
y = data[1:,1]

# Plot the data in histogram
plt.hist(y, bins=100, log=True)
plt.xlabel('Eigenvalues')
plt.ylabel('Frequency')
plt.title('Histogram of eigenvalues')
plt.show()

del(data, x, y)
